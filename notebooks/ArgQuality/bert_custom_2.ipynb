# %% [markdown]
# # **BERT CUSTOM 2**

# %% [markdown]
# ## **ENVIRONMENT SETUP**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q transformers

# %%
# Download the dataset

# !rm -r data*
# !wget http://argumentation.bplaced.net/arguana-data/dagstuhl-15512-argquality-corpus-v2.zip
# !unzip dagstuhl-15512-argquality-corpus-v2.zip
# !rm *.zip
# !rm -r __MACOSX
# !mv dagstuhl-15512-argquality-corpus-v2 data
# Out:
# --2023-04-18 16:00:08--  http://argumentation.bplaced.net/arguana-data/dagstuhl-15512-argquality-corpus-v2.zip
# Resolving argumentation.bplaced.net (argumentation.bplaced.net)... 162.55.0.134, 2a01:4f8:252:1ee::2
# Connecting to argumentation.bplaced.net (argumentation.bplaced.net)|162.55.0.134|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 827888 (808K) [application/zip]
# Saving to: ‘dagstuhl-15512-argquality-corpus-v2.zip’
#
# dagstuhl-15512-argq 100%[===================>] 808.48K   258KB/s    in 3.1s
#
# 2023-04-18 16:00:12 (258 KB/s) - ‘dagstuhl-15512-argquality-corpus-v2.zip’ saved [827888/827888]
#
# Archive:  dagstuhl-15512-argquality-corpus-v2.zip
#    creating: dagstuhl-15512-argquality-corpus-v2/
#   inflating: dagstuhl-15512-argquality-corpus-v2/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/._.DS_Store
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/.DS_Store
#    creating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/._.DS_Store
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219206.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219225.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219244.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219245.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219250.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219258.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219259.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219268.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/no-bad-for-the-economy/arg219293.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219204.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219213.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219220.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219227.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219233.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219254.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/ban-plastic-water-bottles/yes-emergencies-only/arg219261.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg229241.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg229484.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg231491.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg231620.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg240623.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg240625.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg246334.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg270902.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg439197.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/atheism/arg575745.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/christianity/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/christianity/arg229317.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/christianity/arg244440.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/christianity/arg289787.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/christianity/arg636360.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/christianity-or-atheism/christianity/arg644073.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/12567.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/12580.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/12589.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/12592.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/28068.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/70855.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/creation/71559.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/578317615.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/794.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/79918.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/800.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/80854.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/814.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/817.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/822.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/evolution-vs-creation/evolution/823.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/33757.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/389.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/390.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/405.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/415.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/458.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/460.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/468.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/477.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/it-has-a-cute-logo-oh-and-extensions-err-add-ons/76359.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/12365.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/12367.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/12371.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/12380.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/12383.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/12388.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/33187.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/65125.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/firefox-vs-internet-explorer/there-s-more-browsers-than-the-ie-firefox-is-an-animal/65191.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/30529.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/33506.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/46238.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/530.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/63084.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/67160.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/73625.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/76758.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-right/80510.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/12402.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/12414.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/12421.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/12430.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/12431.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/12466.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/31527.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/42624.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/69708.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/gay-marriage-right-or-wrong/allowing-gay-marriage-is-wrong/76796.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg334934.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg334943.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg334968.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg335030.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg335091.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg335095.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg335129.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg335564.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg336179.xmi
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/no/arg336204.xmi
#    creating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/yes/
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-annotated-xmi/human-growth-and-development-should-parents-use-spanking-as-an-option-to-discipline/yes/ar
csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._is-the-school-uniform-a-good-or-bad-idea-_good.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/personal-pursuit-or-advancing-the-common-good-_advancing-the-common-good.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._personal-pursuit-or-advancing-the-common-good-_advancing-the-common-good.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/personal-pursuit-or-advancing-the-common-good-_personal-pursuit.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._personal-pursuit-or-advancing-the-common-good-_personal-pursuit.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/pro-choice-vs-pro-life_pro-choice.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._pro-choice-vs-pro-life_pro-choice.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/pro-choice-vs-pro-life_pro-life.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._pro-choice-vs-pro-life_pro-life.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/should-physical-education-be-mandatory-in-schools-_no-.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._should-physical-education-be-mandatory-in-schools-_no-.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/should-physical-education-be-mandatory-in-schools-_yes-.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._should-physical-education-be-mandatory-in-schools-_yes-.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/tv-is-better-than-books_books.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._tv-is-better-than-books_books.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/tv-is-better-than-books_tv.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._tv-is-better-than-books_tv.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/william-farquhar-ought-to-be-honoured-as-the-rightful-founder-of-singapore_no-it-is-raffles-.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._william-farquhar-ought-to-be-honoured-as-the-rightful-founder-of-singapore_no-it-is-raffles-.csv
#   inflating: dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/william-farquhar-ought-to-be-honoured-as-the-rightful-founder-of-singapore_yes-of-course-.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/dagstuhl-15512-argquality-corpus-unannotated/._william-farquhar-ought-to-be-honoured-as-the-rightful-founder-of-singapore_yes-of-course-.csv
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/._dagstuhl-15512-argquality-corpus-unannotated
#   inflating: dagstuhl-15512-argquality-corpus-v2/README.txt
#   inflating: __MACOSX/dagstuhl-15512-argquality-corpus-v2/._README.txt
#   inflating: __MACOSX/._dagstuhl-15512-argquality-corpus-v2

# %% [markdown]
# ## **IMPORT DATASET**

# %%
import pandas as pd

df = pd.read_csv("data/dagstuhl-15512-argquality-corpus-annotated.csv", sep='\t', encoding_errors="ignore")
df.head(3)
# Out:
#    annotator argumentative overall quality local acceptability  \
# 0          1             y         1 (Low)             1 (Low)
# 1          2             y         1 (Low)            3 (High)
# 2          3             y     2 (Average)         2 (Average)
#
#   appropriateness  arrangement      clarity      cogency effectiveness  \
# 0         1 (Low)      1 (Low)  2 (Average)      1 (Low)       1 (Low)
# 1     2 (Average)  2 (Average)     3 (High)      1 (Low)       1 (Low)
# 2     2 (Average)  2 (Average)  2 (Average)  2 (Average)   2 (Average)
#
#   global acceptability  ... global sufficiency reasonableness local relevance  \
# 0              1 (Low)  ...            1 (Low)        1 (Low)         1 (Low)
# 1             3 (High)  ...            1 (Low)    2 (Average)     2 (Average)
# 2          2 (Average)  ...        2 (Average)    2 (Average)        3 (High)
#
#    credibility emotional appeal  sufficiency  \
# 0      1 (Low)          1 (Low)      1 (Low)
# 1  2 (Average)      2 (Average)      1 (Low)
# 2  2 (Average)          1 (Low)  2 (Average)
#
#                                             argument        #id  \
# 0  it is true that bottled water is a waste, but ...  arg219250
# 1  it is true that bottled water is a waste, but ...  arg219250
# 2  it is true that bottled water is a waste, but ...  arg219250
#
#                        issue                  stance
# 0  ban-plastic-water-bottles  no-bad-for-the-economy
# 1  ban-plastic-water-bottles  no-bad-for-the-economy
# 2  ban-plastic-water-bottles  no-bad-for-the-economy
#
# [3 rows x 21 columns]

# %%
import numpy as np

print(f"Number of annotations = {len(df['argument'])}")
print(f"Number of unique arguements = {len(np.unique(df['argument']))}") # Each argument was scored by 3 annotators
print(f"Number of unique issue = {len(np.unique(df['issue']))}")  # There are a total of 16 issues
print(f"Number of unique stance = {len(np.unique(df['stance']))}") # Each issue has on an avg 2 stance (positive and negative)
# Out:
# Number of annotations = 960
# Number of unique arguements = 320
# Number of unique issue = 16
# Number of unique stance = 28

# %% [markdown]
# ### Remove non-arguments

# %%
df = df[df["argumentative"] == "y"]

# %%
print(f"Number of annotations = {len(df['argument'])}")
print(f"Number of unique arguements = {len(np.unique(df['argument']))}") # Each argument was scored by 3 annotators
print(f"Number of unique issue = {len(np.unique(df['issue']))}")  # There are a total of 16 issues
print(f"Number of unique stance = {len(np.unique(df['stance']))}") # Each issue has on an avg 2 stance (positive and negative)
# Out:
# Number of annotations = 935
# Number of unique arguements = 316
# Number of unique issue = 16
# Number of unique stance = 28

# %% [markdown]
# ### Consolidate annotator scores

# %%
argument = np.unique(df["argument"])

attributes = ["annotator", "overall quality", "cogency", "effectiveness", "reasonableness", "argument", "#id", "issue"]

cleaned_df = []

for arg in argument:

    new_df = df[df["argument"] == arg][attributes]
    flag = 0
    new_dict = {
        "#id": new_df["#id"].iloc[0],
        "argument": new_df["argument"].iloc[0],
        "issue": new_df["issue"].iloc[0],
    }

    for ele in ["overall quality", "cogency", "effectiveness", "reasonableness"]:
        if len(pd.value_counts(new_df[ele])) == 3:
            flag = 1
            break
        new_dict[ele] = pd.value_counts(new_df[ele]).index[0]
        
    if flag == 1:
        continue
    cleaned_df.append(new_dict)

# %%
df = pd.DataFrame(cleaned_df)

# %%
print(f"Number of annotations = {len(df['argument'])}")
print(f"Number of unique arguements = {len(np.unique(df['argument']))}") # Each argument was scored by 3 annotators
# Out:
# Number of annotations = 273
# Number of unique arguements = 273

# %% [markdown]
# ### Perform train-test split

# %%
df_train = df.sample(frac=0.8, random_state=101)
df_test = df.drop(df_train.index)

# %% [markdown]
# ### Display Dataset Metrics

# %%
print(f"Length of dataset = {len(df)}")
print(f"Number of training data = {len(df_train)}")
print(f"Number of testing data = {len(df_test)}")
# Out:
# Length of dataset = 273
# Number of training data = 218
# Number of testing data = 55

# %%
print(f"Number of Classes = {len(np.unique(df['overall quality']))}")

for label in np.unique(df["overall quality"]):
    print(f"Number of Class {label} in training data = {len(df_train[df_train['overall quality']==label])}")
    print(f"Number of Class {label} in testing data = {len(df_test[df_test['overall quality']==label])}")
# Out:
# Number of Classes = 3
# Number of Class 1 (Low) in training data = 128
# Number of Class 1 (Low) in testing data = 31
# Number of Class 2 (Average) in training data = 77
# Number of Class 2 (Average) in testing data = 21
# Number of Class 3 (High) in training data = 13
# Number of Class 3 (High) in testing data = 3

# %% [markdown]
# ## **TEXT CLEANING**

# %%
import re

# %%
def clean_text_bert(text):
    text = text.lower() # Convert the text into lowercase
    text = text.replace('</br>', '') # Remove </br>
    text = text.replace('\n', '') # Remove \n
    
    # Remove quotes
    text = re.sub(r"\'", "", text) 
    text = re.sub(r"\"", "", text) 
    
    text = re.sub(r"[^\w]", " ", text) # Remove all symbols

    text = re.sub(r'[ ]{2,}', ' ', text) # Remove extra spaces
    text = re.sub(r'[ \t]+$', '', text) # Remove trailing white spaces
    
    return text

# %%
df_train["argument"] = df_train["argument"].apply(clean_text_bert)
df_test["argument"] = df_test["argument"].apply(clean_text_bert)

df_train["issue"] = df_train["issue"].apply(clean_text_bert)
df_test["issue"] = df_test["issue"].apply(clean_text_bert)

# %%
df_train["argument"]
# Out:
# 33     do we have the potential br yes br the only co...
# 13     americans spend billions on bottled water ever...
# 189    thats your best argument because they dont br ...
# 269    yes because if they fear getting hit than they...
# 135    kids are fat these days p e helps 1 one br and...
#                              ...
# 97     i think that personal pursuit is more importan...
# 207    u s alone grew by over 13 according to researc...
# 203    theres no reason at all why anyone could say i...
# 17     as an ambitious young person wanting to become...
# 140    murder under any circumstance is not right a p...
# Name: argument, Length: 218, dtype: object

# %%
df_train["issue"]
# Out:
# 33             india has the potential to lead the world
# 13                             ban plastic water bottles
# 189                                evolution vs creation
# 269    human growth and development should parents us...
# 135    should physical education be mandatory in schools
#                              ...
# 97         personal pursuit or advancing the common good
# 207                            ban plastic water bottles
# 203                         firefox vs internet explorer
# 17     if your spouse committed murder and he or she ...
# 140    if your spouse committed murder and he or she ...
# Name: issue, Length: 218, dtype: object

# %% [markdown]
# ### Augment argument with issue

# %%
df_train["argument"] = df_train["issue"] + " [SEP] " + df_train["argument"]
df_test["argument"] = df_test["issue"] + " [SEP] " + df_test["argument"]

# %%
df_train["argument"]
# Out:
# 33     india has the potential to lead the world [SEP...
# 13     ban plastic water bottles [SEP] americans spen...
# 189    evolution vs creation [SEP] thats your best ar...
# 269    human growth and development should parents us...
# 135    should physical education be mandatory in scho...
#                              ...
# 97     personal pursuit or advancing the common good ...
# 207    ban plastic water bottles [SEP] u s alone grew...
# 203    firefox vs internet explorer [SEP] theres no r...
# 17     if your spouse committed murder and he or she ...
# 140    if your spouse committed murder and he or she ...
# Name: argument, Length: 218, dtype: object

# %% [markdown]
# ## **PRE-CONFIG FOR BERT**

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
MAX_LEN = np.max([
    np.max([len(x) for x in df_train["argument"]]), 
    np.max([len(x) for x in df_test["argument"]])
])

if MAX_LEN > 510:  # Limit of the BERT model
    MAX_LEN = 510

BATCH_SIZE = 16
LEARNING_RATE = 1e-5

# %% [markdown]
# ## **BUILD DATASET FOR BERT**

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
from torch.utils.data import Dataset

class ModelDataset(Dataset):
    def __init__(self, X, y, tokenizer, max_len):
        self.df = df
        self.max_len = max_len
        self.text = X
        self.tokenizer = tokenizer
        self.targets = y
        
    def __len__(self):
        return len(self.targets)
    
    def __getitem__(self, index):
        text = self.text[index]
        inputs = self.tokenizer.encode_plus(
            text,
            truncation=True,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]
        
        return {
            'ids': torch.tensor(ids, dtype=torch.long).to(device),
            'mask': torch.tensor(mask, dtype=torch.long).to(device),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long).to(device),
            'targets': torch.tensor(self.targets[index], dtype=torch.float).to(device)
        }

# %%
X_train = np.array(df_train["argument"])
X_test = np.array(df_test["argument"])

# %%
y_train = df_train["overall quality"]
y_test = df_test["overall quality"]

encoder = {
    "1 (Low)": [1, 0, 0],
    "2 (Average)": [0, 1, 0],
    "3 (High)": [0, 0, 1],
}

y_train = np.array([encoder[ele] for ele in y_train])
y_test = np.array([encoder[ele] for ele in y_test])

# %%
train_data = ModelDataset(X_train, y_train, tokenizer, MAX_LEN)
test_data = ModelDataset(X_test, y_test, tokenizer, MAX_LEN)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %% [markdown]
# ## **BUILD CUSTOM MODEL**

# %%
from torch import nn
from transformers import AutoModel

class CustomModel(nn.Module):
    
    def __init__(self):
        super(CustomModel, self).__init__()
        self.bert = AutoModel.from_pretrained('bert-base-uncased')
        self.stack = nn.Sequential(
            nn.Linear(768, 512),
            nn.ReLU(),
            nn.Linear(512, 32),
            nn.ReLU(),
            nn.Linear(32, 3),
        )

    def forward(self, ids, mask, token_type_ids):
        _, features = self.bert(
            ids, token_type_ids=token_type_ids,
            attention_mask=mask, return_dict=False
        )
        output = self.stack(features)
        return output

# %%
model = CustomModel().to(device)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## **TRAIN MODEL**

# %%
loss_fn = nn.BCEWithLogitsLoss() # Loss function
optimizer = torch.optim.AdamW(params=model.parameters(), lr=LEARNING_RATE) # Optimizer

# %%
# Define function to train the model

from tqdm import tqdm

def train(epoch):
    
    model.train()
    
    # for batch in tqdm(train_loader):
    for batch in train_loader:
        
        optimizer.zero_grad()
        
        ids = batch['ids'].to(device, dtype = torch.long)
        mask = batch['mask'].to(device, dtype = torch.long)
        token_type_ids = batch['token_type_ids'].to(device, dtype = torch.long)
        targets = batch['targets'].to(device, dtype = torch.float)

        outputs = model(ids, mask, token_type_ids)

        loss = loss_fn(outputs, targets)
        
        loss.backward()
        optimizer.step()
        
        
    # print(f'Epoch: {epoch + 1}, Loss:  {loss.item()}')

# %%
# Define function for model evaluation

def validation(data_loader):
    
    model.eval()
    targets = []
    outputs = []
    
    with torch.no_grad():
        
        for batch in data_loader:
            
            ids = batch['ids'].to(device, dtype = torch.long)
            mask = batch['mask'].to(device, dtype = torch.long)
            token_type_ids = batch['token_type_ids'].to(device, dtype = torch.long)
            batch_targets = batch['targets'].to(device, dtype = torch.float)
            
            batch_outputs = model(ids, mask, token_type_ids)
            
            targets.extend(batch_targets.cpu().numpy().tolist())
            outputs.extend(batch_outputs.cpu().numpy().tolist())
            
    return outputs, targets

# %%
# Perform model training

from copy import deepcopy
from sklearn import metrics

best_score = -np.inf
best_weights = None
history = []

EPOCHS = 100

for epoch in tqdm(range(EPOCHS)):
    train(epoch)

    outputs, targets = validation(test_loader)

    targets = [np.argmax(x) for x in targets]
    outputs = [np.argmax(x) for x in outputs]
    score = metrics.f1_score(targets, outputs, average='weighted')

    history.append(score)
    # print(f"Validation f1-score: {score:>.4f}")

    if score > best_score:
        best_score = score
        best_weights = deepcopy(model.state_dict())
        torch.save(best_weights, "/content/drive/MyDrive/bert_argqual_custom_2.pt")
# Out:
# 100%|██████████| 100/100 [35:38<00:00, 21.38s/it]

# %% [markdown]
# ## **EVALUATE CUSTOM MODEL**

# %%
model.load_state_dict(best_weights)
outputs, targets = validation(test_loader)
targets = [np.argmax(x) for x in targets]
outputs = [np.argmax(x) for x in outputs]

# %%
accuracy = metrics.accuracy_score(targets, outputs)
f1_score_w_avg = metrics.f1_score(targets, outputs, average='weighted')

print(f"Accuracy Score = {accuracy}")
print(f"F1 Score (Weighted) = {f1_score_w_avg}")

print(metrics.classification_report(targets, outputs))
# Out:
# Accuracy Score = 0.6727272727272727
# F1 Score (Weighted) = 0.6517482517482518
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77        31
#            1       0.57      0.57      0.57        21
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.67        55
#    macro avg       0.44      0.46      0.45        55
# weighted avg       0.63      0.67      0.65        55
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## **SAVE MODEL**

# %%
torch.save(best_weights, "./bert_argqual_custom_2.pt")
torch.save(best_weights, "/content/drive/MyDrive/bert_argqual_custom_2.pt")

# %%
saved_model = CustomModel().to(device)
saved_model.load_state_dict(torch.load("./bert_argqual_custom_2.pt"))
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
saved_model.eval()

targets = []
outputs = []

with torch.no_grad():
    for batch in test_loader:
        ids = batch['ids'].to(device, dtype = torch.long)
        mask = batch['mask'].to(device, dtype = torch.long)
        token_type_ids = batch['token_type_ids'].to(device, dtype = torch.long)
        batch_targets = batch['targets'].to(device, dtype = torch.float)
        
        batch_outputs = saved_model(ids, mask, token_type_ids)
        
        targets.extend(batch_targets.cpu().numpy().tolist())
        outputs.extend(batch_outputs.cpu().numpy().tolist())

# %%
targets = [np.argmax(x) for x in targets]
outputs = [np.argmax(x) for x in outputs]
accuracy = metrics.accuracy_score(targets, outputs)
f1_score_w_avg = metrics.f1_score(targets, outputs, average='weighted')

print(f"Accuracy Score = {accuracy}")
print(f"F1 Score (Weighted) = {f1_score_w_avg}")

print(metrics.classification_report(targets, outputs))
# Out:
# Accuracy Score = 0.6727272727272727
# F1 Score (Weighted) = 0.6517482517482518
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77        31
#            1       0.57      0.57      0.57        21
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.67        55
#    macro avg       0.44      0.46      0.45        55
# weighted avg       0.63      0.67      0.65        55
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
